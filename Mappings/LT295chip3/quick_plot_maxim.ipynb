# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib widget

# %%
master_array = np.loadtxt("LT295chip3_master.txt", delimiter=',', skiprows=1)
f0 = master_array[:, 6]
kid_id_board = np.ones((20, 20), dtype=int)
kid_id_board[master_array[:,1].astype(int), master_array[:,2].astype(int)] = master_array[:,0]

# %%
fig, ax = plt.subplots()
ax.imshow(f0[kid_id_board], cmap='viridis', origin='lower')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
